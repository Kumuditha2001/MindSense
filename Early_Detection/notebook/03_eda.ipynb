# %%
import pandas as pd

df = pd.read_csv(r"D:\project\MindSense\Early_Detection\data\raw\student_data.csv.csv")

# Remove duplicate header row
df = df[df["Timestamp"] != "Timestamp"]

# Convert timestamp
df["Timestamp"] = pd.to_datetime(df["Timestamp"])

# Convert numeric columns
numeric_columns = [
    "Heart_Rate",
    "Blood_Pressure_Systolic",
    "Blood_Pressure_Diastolic",
    "Respiration_Rate",
    "Sleep_Duration",
    "Activity_Levels",
    "Cognitive_Load",
    "Study_Hours",
    "Academic_Stressors"
]

for col in numeric_columns:
    df[col] = pd.to_numeric(df[col])

# Sort
df = df.sort_values(["StudentID", "Timestamp"])

# %%
import matplotlib.pyplot as plt

# %%
df["Mental_Health_Status"].value_counts().plot(kind="bar")

plt.title("Mental Health Status Distribution")
plt.xlabel("Mental Health Status")
plt.ylabel("Count")

plt.show()

# %%
df["Stress_Level"].value_counts().plot(kind="bar")

plt.title("Stress Level Distribution")
plt.xlabel("Stress Level")
plt.ylabel("Count")

plt.show()

# %%
df["Mood"].value_counts().plot(kind="bar")

plt.title("Mood Distribution")
plt.xlabel("Mood")
plt.ylabel("Count")

plt.show()

# %%
import matplotlib.pyplot as plt

numeric_columns = [
    "Heart_Rate",
    "Blood_Pressure_Systolic",
    "Blood_Pressure_Diastolic",
    "Respiration_Rate",
    "Sleep_Duration",
    "Activity_Levels",
    "Cognitive_Load",
    "Study_Hours",
    "Academic_Stressors"
]

correlation = df[numeric_columns].corr()

plt.figure(figsize=(8,6))
plt.imshow(correlation)

plt.xticks(range(len(numeric_columns)), numeric_columns, rotation=90)
plt.yticks(range(len(numeric_columns)), numeric_columns)

plt.colorbar()

plt.title("Correlation Matrix")

plt.show()

# %%
student1 = df[df["StudentID"] == "1"]

plt.figure(figsize=(12,4))

plt.plot(student1["Timestamp"], student1["Heart_Rate"])

plt.title("Heart Rate Over Time (Student 1)")
plt.xlabel("Date")
plt.ylabel("Heart Rate")

plt.show()

# %%
plt.figure(figsize=(12,4))

plt.plot(student1["Timestamp"], student1["Sleep_Duration"])

plt.title("Sleep Duration Over Time (Student 1)")
plt.xlabel("Date")
plt.ylabel("Sleep Duration")

plt.show()

# %%
plt.figure(figsize=(12,4))

plt.plot(student1["Timestamp"], student1["Sleep_Duration"])

plt.title("Sleep Duration Over Time (Student 1)")
plt.xlabel("Date")
plt.ylabel("Sleep Duration")

plt.show()

# %%
plt.figure(figsize=(12,4))

plt.plot(student1["Timestamp"], student1["Academic_Stressors"])

plt.title("Academic Stressors Over Time")
plt.xlabel("Date")
plt.ylabel("Academic Stressors")

plt.show()

# %%
plt.savefig("D:/project/MindSense/Early_Detection/graphs/heart_rate_student1.png", dpi=300, bbox_inches="tight")

# %%
plt.figure(figsize=(12,4))

plt.plot(student1["Timestamp"], student1["Heart_Rate"])

plt.title("Heart Rate Over Time (Student 1)")
plt.xlabel("Date")
plt.ylabel("Heart Rate")

plt.savefig(
    "D:/project/MindSense/Early_Detection/graphs/heart_rate_student1.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(12,4))

plt.plot(student1["Timestamp"], student1["Sleep_Duration"])

plt.title("Sleep Duration Over Time (Student 1)")
plt.xlabel("Date")
plt.ylabel("Sleep Duration (hours)")

plt.savefig(
    "D:/project/MindSense/Early_Detection/graphs/sleep_duration_student1.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(12,4))

plt.plot(student1["Timestamp"], student1["Stress_Level"])

plt.title("Stress Level Over Time (Student 1)")
plt.xlabel("Date")
plt.ylabel("Stress Level")

plt.savefig(
    "D:/project/MindSense/Early_Detection/graphs/stress_level_student1.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(12,4))

plt.plot(student1["Timestamp"], student1["Mental_Health_Status"])

plt.title("Mental Health Status Over Time (Student 1)")
plt.xlabel("Date")
plt.ylabel("Mental Health Status")

plt.savefig(
    "D:/project/MindSense/Early_Detection/graphs/mental_health_student1.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
df = pd.read_csv(
"D:/project/MindSense/Early_Detection/data/processed/cleaned_student_data.csv"
)

df["Timestamp"] = pd.to_datetime(df["Timestamp"])

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(
    r"D:\project\MindSense\Early_Detection\data\processed\cleaned_student_data.csv"
)

df.head()
# Out:
#    StudentID        Profile   Timestamp  Heart_Rate  Blood_Pressure_Systolic  \
# 0          1  High_Achiever  2015-01-01        74.9                    116.9
# 1          1  High_Achiever  2015-01-02        69.8                    120.2
# 2          1  High_Achiever  2015-01-03        69.5                    113.7
# 3          1  High_Achiever  2015-01-04        70.8                    114.6
# 4          1  High_Achiever  2015-01-05        70.2                    117.1
#
#    Blood_Pressure_Diastolic  Respiration_Rate  Sleep_Duration  \
# 0                      74.2              15.4            7.24
# 1                      74.0              14.7            6.16
# 2                      75.3              15.6            7.33
# 3                      79.4              15.2            7.22
# 4                      75.5              15.2            7.10
#
#    Activity_Levels  Mood  Cognitive_Load  Study_Hours  Academic_Stressors  \
# ...

# %%
df["Timestamp"] = pd.to_datetime(df["Timestamp"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38650 entries, 0 to 38649
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   StudentID                 38650 non-null  int64
#  1   Profile                   38650 non-null  str
#  2   Timestamp                 38650 non-null  datetime64[us]
#  3   Heart_Rate                38650 non-null  float64
#  4   Blood_Pressure_Systolic   38650 non-null  float64
#  5   Blood_Pressure_Diastolic  38650 non-null  float64
#  6   Respiration_Rate          38650 non-null  float64
#  7   Sleep_Duration            38650 non-null  float64
#  8   Activity_Levels           38650 non-null  int64
#  9   Mood                      38650 non-null  int64
#  10  Cognitive_Load            38650 non-null  int64
#  11  Study_Hours               38650 non-null  float64
#  12  Academic_Stressors        38650 non-null  int64
# ...

# %%
df.shape
# Out:
# (38650, 15)

# %%
df["Mental_Health_Status"].value_counts().plot(kind="bar")

plt.title("Mental Health Status Distribution")
plt.xlabel("Mental Health Status")
plt.ylabel("Count")

plt.show()

# %%
df["Stress_Level"].value_counts().plot(kind="bar")

plt.title("Stress Level Distribution")
plt.xlabel("Stress Level")
plt.ylabel("Count")

plt.show()

# %%
df["Mood"].value_counts().plot(kind="bar")

plt.title("Mood Distribution")
plt.xlabel("Mood")
plt.ylabel("Count")

plt.show()

# %%
student1 = df[df["StudentID"] == 1]

student1.head()
# Out:
#    StudentID        Profile  Timestamp  Heart_Rate  Blood_Pressure_Systolic  \
# 0          1  High_Achiever 2015-01-01        74.9                    116.9
# 1          1  High_Achiever 2015-01-02        69.8                    120.2
# 2          1  High_Achiever 2015-01-03        69.5                    113.7
# 3          1  High_Achiever 2015-01-04        70.8                    114.6
# 4          1  High_Achiever 2015-01-05        70.2                    117.1
#
#    Blood_Pressure_Diastolic  Respiration_Rate  Sleep_Duration  \
# 0                      74.2              15.4            7.24
# 1                      74.0              14.7            6.16
# 2                      75.3              15.6            7.33
# 3                      79.4              15.2            7.22
# 4                      75.5              15.2            7.10
#
#    Activity_Levels  Mood  Cognitive_Load  Study_Hours  Academic_Stressors  \
# ...

# %%
plt.figure(figsize=(12,4))

plt.plot(
    student1["Timestamp"],
    student1["Mental_Health_Status"]
)

plt.title("Mental Health Status Trend - Student 1")
plt.xlabel("Date")
plt.ylabel("Mental Health Status")

plt.show()

# %%
plt.figure(figsize=(12,4))

plt.plot(
    student1["Timestamp"],
    student1["Sleep_Duration"]
)

plt.title("Sleep Duration Trend - Student 1")
plt.xlabel("Date")
plt.ylabel("Sleep Hours")

plt.show()

# %%
plt.figure(figsize=(12,4))

plt.plot(
    student1["Timestamp"],
    student1["Academic_Stressors"]
)

plt.title("Academic Stress Trend - Student 1")
plt.xlabel("Date")
plt.ylabel("Stressors")

plt.show()
